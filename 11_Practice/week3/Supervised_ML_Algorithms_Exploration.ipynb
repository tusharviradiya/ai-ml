# %% [markdown]
# <a href="https://colab.research.google.com/github/tusharviradiya/ai-ml/blob/main/11_Practice/week3/Supervised_ML_Algorithms_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==============================================================================
# 1. SUMMARY GUIDE: SUPERVISED LEARNING ALGORITHMS
# ==============================================================================
# Run this cell to display the algorithm exploration summary
import pandas as pd

algo_summary = pd.DataFrame(
    [
        {
            "Algorithm": "Linear / Ridge / Lasso Regression",
            "Type": "Regression",
            "Core Purpose": "Models linear relationship between features and continuous target",
            "Best Use Case": "Pricing, financial forecasting, sales trend modeling",
            "Key Scikit-Learn Class": "LinearRegression, Ridge, Lasso",
        },
        {
            "Algorithm": "Logistic Regression",
            "Type": "Classification",
            "Core Purpose": "Estimates log-odds probability for categorical outcomes",
            "Best Use Case": "Churn prediction, spam filtering, credit default",
            "Key Scikit-Learn Class": "LogisticRegression",
        },
        {
            "Algorithm": "Decision Tree",
            "Type": "Classification & Regression",
            "Core Purpose": "Partitions data using orthogonal feature split rules",
            "Best Use Case": "Explainable rule-based systems, medical triage",
            "Key Scikit-Learn Class": "DecisionTreeClassifier, DecisionTreeRegressor",
        },
        {
            "Algorithm": "Random Forest",
            "Type": "Classification & Regression",
            "Core Purpose": "Ensemble of bagging trees with feature subspace sampling",
            "Best Use Case": "Tabular benchmarks, fraud detection, risk scoring",
            "Key Scikit-Learn Class": "RandomForestClassifier, RandomForestRegressor",
        },
        {
            "Algorithm": "Gradient Boosting (GBM)",
            "Type": "Classification & Regression",
            "Core Purpose": "Sequentially optimizes pseudo-residuals of weak learners",
            "Best Use Case": "Competitive tabular ML, CTR prediction, ranking",
            "Key Scikit-Learn Class": "GradientBoostingClassifier, GradientBoostingRegressor",
        },
        {
            "Algorithm": "Support Vector Machines (SVM)",
            "Type": "Classification & Regression",
            "Core Purpose": "Finds maximal margin hyperplane via kernel transformations",
            "Best Use Case": "Bioinformatics, text categorization, image embeddings",
            "Key Scikit-Learn Class": "SVC, SVR",
        },
        {
            "Algorithm": "K-Nearest Neighbors (KNN)",
            "Type": "Classification & Regression",
            "Core Purpose": "Instance-based majority voting or average of k-neighbors",
            "Best Use Case": "Spatial data, recommendation systems, baseline modeling",
            "Key Scikit-Learn Class": "KNeighborsClassifier, KNeighborsRegressor",
        },
        {
            "Algorithm": "Naive Bayes",
            "Type": "Classification",
            "Core Purpose": "Applies Bayes theorem assuming feature conditional independence",
            "Best Use Case": "NLP text classification, sentiment analysis, document tagging",
            "Key Scikit-Learn Class": "GaussianNB, MultinomialNB",
        },
    ]
)

display(algo_summary)
# Out:
#                            Algorithm                         Type  \
# 0  Linear / Ridge / Lasso Regression                   Regression
# 1                Logistic Regression               Classification
# 2                      Decision Tree  Classification & Regression
# 3                      Random Forest  Classification & Regression
# 4            Gradient Boosting (GBM)  Classification & Regression
# 5      Support Vector Machines (SVM)  Classification & Regression
# 6          K-Nearest Neighbors (KNN)  Classification & Regression
# 7                        Naive Bayes               Classification
#
#                                         Core Purpose  \
# 0  Models linear relationship between features an...
# 1  Estimates log-odds probability for categorical...
# 2  Partitions data using orthogonal feature split...
# 3  Ensemble of bagging trees with feature subspac...
# 4  Sequentially optimizes pseudo-residuals of wea...
# ...
