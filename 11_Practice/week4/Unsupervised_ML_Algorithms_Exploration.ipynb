# %% [markdown]
# <a href="https://colab.research.google.com/github/tusharviradiya/ai-ml/blob/main/11_Practice/week4/Unsupervised_ML_Algorithms_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==============================================================================
# 1. SUMMARY GUIDE: UNSUPERVISED LEARNING ALGORITHMS
# ==============================================================================
import pandas as pd

algo_summary = pd.DataFrame(
    [
        {
            "Algorithm": "K-Means Clustering",
            "Type": "Clustering (Centroid-based)",
            "Core Purpose": "Partitions data into K non-overlapping spherical clusters minimizing inertia",
            "Best Use Case": "Customer segmentation, store location planning",
            "Key Scikit-Learn Class": "KMeans",
        },
        {
            "Algorithm": "Hierarchical (Agglomerative)",
            "Type": "Clustering (Hierarchical)",
            "Core Purpose": "Builds a bottom-up cluster tree (dendrogram) using linkage criteria",
            "Best Use Case": "Gene taxonomy, document hierarchies",
            "Key Scikit-Learn Class": "AgglomerativeClustering",
        },
        {
            "Algorithm": "DBSCAN",
            "Type": "Clustering (Density-based)",
            "Core Purpose": "Groups high-density core points; isolates arbitrary shapes & flags noise/outliers",
            "Best Use Case": "Spatial GPS anomaly detection, non-linear shapes",
            "Key Scikit-Learn Class": "DBSCAN",
        },
        {
            "Algorithm": "Principal Component Analysis (PCA)",
            "Type": "Dimensionality Reduction (Linear)",
            "Core Purpose": "Projects correlated features onto orthogonal axes of maximum variance",
            "Best Use Case": "Feature compression, 2D/3D visualization, noise reduction",
            "Key Scikit-Learn Class": "PCA",
        },
        {
            "Algorithm": "t-SNE / UMAP",
            "Type": "Dimensionality Reduction (Non-linear)",
            "Core Purpose": "Preserves local neighborhood distances in low-dimensional space",
            "Best Use Case": "High-dimensional manifold inspection, image embeddings",
            "Key Scikit-Learn Class": "TSNE",
        },
        {
            "Algorithm": "Isolation Forest",
            "Type": "Anomaly Detection",
            "Core Purpose": "Isolates anomalous observations using random recursive splits",
            "Best Use Case": "Fraud detection, server metric anomaly monitoring",
            "Key Scikit-Learn Class": "IsolationForest",
        },
    ]
)

display(algo_summary)
# Out:
#                             Algorithm                                   Type  \
# 0                  K-Means Clustering            Clustering (Centroid-based)
# 1        Hierarchical (Agglomerative)              Clustering (Hierarchical)
# 2                              DBSCAN             Clustering (Density-based)
# 3  Principal Component Analysis (PCA)      Dimensionality Reduction (Linear)
# 4                        t-SNE / UMAP  Dimensionality Reduction (Non-linear)
# 5                    Isolation Forest                      Anomaly Detection
#
#                                         Core Purpose  \
# 0  Partitions data into K non-overlapping spheric...
# 1  Builds a bottom-up cluster tree (dendrogram) u...
# 2  Groups high-density core points; isolates arbi...
# 3  Projects correlated features onto orthogonal a...
# 4  Preserves local neighborhood distances in low-...
# 5  Isolates anomalous observations using random r...
#
# ...
