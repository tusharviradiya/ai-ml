# %% [markdown]
# <a href="https://colab.research.google.com/github/tusharviradiya/ai-ml/blob/main/11_Practice/week2/ML_Problem_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# | # | Real-World Problem | ML Paradigm | Recommended Algorithm | Rationale |
# | --- | --- | --- | --- | --- |
# | **1** | Predicting whether a credit card transaction is fraudulent | Supervised (Classification) | Random Forest / XGBoost | Labeled historical transaction data with high class imbalance. |
# | **2** | Predicting house selling prices based on square footage & location | Supervised (Regression) | Gradient Boosted Trees / Ridge Regression | Continuous numerical target variable with labeled features. |
# | **3** | Customer segmentation for targeted marketing campaigns | Unsupervised (Clustering) | K-Means / DBSCAN | No ground-truth labels; discovers organic customer behavioral groupings. |
# | **4** | Autonomous drone navigation & obstacle avoidance | Reinforcement Learning | Deep Q-Network (DQN) / PPO | Agent learns continuous action policy via environment rewards/penalties. |
# | **5** | Email Spam vs. Ham filtering | Supervised (Classification) | Naive Bayes / Logistic Regression | Binary classification on high-dimensional text-token frequencies. |
# | **6** | Product recommendation engine on e-commerce platforms | Unsupervised / Collaborative Filtering | Matrix Factorization (SVD) / Autoencoders | Uncovers latent preference dimensions across user-item interaction matrices. |
# | **7** | Optimizing real-time traffic signal timing | Reinforcement Learning | Deep Deterministic Policy Gradient (DDPG) | Dynamically optimizes vehicle throughput based on state feedback. |
# | **8** | Compressing 100+ sensor metrics into key diagnostic signals | Unsupervised (Dimensionality Reduction) | Principal Component Analysis (PCA) | Projects high-dimensional feature space onto maximum variance orthogonal components. |
# | **9** | Diagnosing pneumonia from chest X-ray scans | Supervised (Classification) | Convolutional Neural Networks (CNN) | Labeled image classification identifying spatial pathologies. |
# | **10** | Game playing AI (e.g., Chess / Go) | Reinforcement Learning | Monte Carlo Tree Search + Policy Gradients (AlphaZero) | Learns winning heuristics through self-play state evaluation. |
