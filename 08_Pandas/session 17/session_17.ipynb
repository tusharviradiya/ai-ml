# %% [markdown]
# ### Creating Dataframe

# %%
import numpy as np
import pandas as pd

# %%
student_data = [
    [100, 90, 10, 'tushar'],
    [90, 80, 7, 'ram'],
    [110, 95, 14, 'laksham'],
    [120, 97, 30, 'veer'],
]
student_data
# Out:
# [[100, 90, 10, 'tushar'],
#  [90, 80, 7, 'ram'],
#  [110, 95, 14, 'laksham'],
#  [120, 97, 30, 'veer']]

# %%
# using list
student = pd.DataFrame(student_data,columns=['iq','marks','package', 'name'])
print(type(student))
student
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     iq  marks  package     name
# 0  100     90       10   tushar
# 1   90     80        7      ram
# 2  110     95       14  laksham
# 3  120     97       30     veer

# %%
# using read_csv()
movies = pd.read_csv('../datasets/movies.csv')
type(movies)
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 35071   152579                       Lagaan (2001)
# 35072   152580          Hum Aapke Hain Koun (1994)
# 35073   152581                    Khalnayak (1993)
# 35074   152583                         Darr (1993)
# 35075   152584                         Beta (1992)
#
#                                              genres
# 0       Adventure|Animation|Children|Comedy|Fantasy
# 1                        Adventure|Children|Fantasy
# 2                                    Comedy|Romance
# 3                              Comedy|Drama|Romance
# 4                                            Comedy
# ...

# %%
ipl = pd.read_csv('../datasets/ipl_matches_2.csv')
ipl
# Out:
#                             team1                        team2  match_date  \
# 0     Royal Challengers Bangalore        Kolkata Knight Riders  2008-04-18
# 1                 Kings XI Punjab          Chennai Super Kings  2008-04-19
# 2                Delhi Daredevils             Rajasthan Royals  2008-04-19
# 3                  Mumbai Indians  Royal Challengers Bangalore  2008-04-20
# 4           Kolkata Knight Riders              Deccan Chargers  2008-04-20
# ...                           ...                          ...         ...
# 1164         Lucknow Super Giants  Royal Challengers Bengaluru  2025-05-27
# 1165                 Punjab Kings  Royal Challengers Bengaluru  2025-05-29
# 1166               Mumbai Indians               Gujarat Titans  2025-05-30
# 1167               Mumbai Indians                 Punjab Kings  2025-06-01
# 1168  Royal Challengers Bengaluru                 Punjab Kings  2025-06-03
#
# ...

# %% [markdown]
# ### Dataframe Methods and Attributes

# %%
# shapes
print(movies.shape)
print(ipl.shape)
# Out:
# (35076, 3)
# (1169, 19)

# %%
# dtype
movies.dtypes
# Out:
# movieId     int64
# title      object
# genres     object
# dtype: object

# %%
# index
movies.index
# Out:
# RangeIndex(start=0, stop=35076, step=1)

# %%
# column
print(movies.columns)
print(ipl.columns)
print(student.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')
# Index(['team1', 'team2', 'match_date', 'toss_winner', 'toss_decision',
#        'winner', 'player_of_match', 'venue', 'city', 'team1_players',
#        'team2_players', 'season', 'match_number', 'match_type', 'result',
#        'result_margin', 'target_runs', 'target_overs', 'super_over'],
#       dtype='object')
# Index(['iq', 'marks', 'package', 'name'], dtype='object')

# %%
# values
# print(student.values)
print(movies.values)
# print(ipl.values)
# Out:
# [[1 'Toy Story (1995)' 'Adventure|Animation|Children|Comedy|Fantasy']
#  [2 'Jumanji (1995)' 'Adventure|Children|Fantasy']
#  [3 'Grumpier Old Men (1995)' 'Comedy|Romance']
#  ...
#  [152581 'Khalnayak (1993)' 'Bollywood|Crime|Action']
#  [152583 'Darr (1993)' 'Bollywood|Thriller']
#  [152584 'Beta (1992)' 'Bollywood|Drama']]

# %%
# head and tail
# movies.head(5)
movies.tail(5)
# Out:
#        movieId                       title  \
# 35071   152579               Lagaan (2001)
# 35072   152580  Hum Aapke Hain Koun (1994)
# 35073   152581            Khalnayak (1993)
# 35074   152583                 Darr (1993)
# 35075   152584                 Beta (1992)
#
#                                              genres
# 35071  Bollywood|Period|Drama|Sports|Comedy|Romance
# 35072         Bollywood|Drama|Musical|Comedy|Family
# 35073                        Bollywood|Crime|Action
# 35074                            Bollywood|Thriller
# 35075                               Bollywood|Drama

# %%
# sample
movies.sample()
# Out:
#        movieId                                              title  \
# 20578   100463  Quackser Fortune Has a Cousin in the Bronx (1970)
#
#                      genres
# 20578  Comedy|Drama|Romance

# %%
# info
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35076 entries, 0 to 35075
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  35076 non-null  int64
#  1   title    35076 non-null  object
#  2   genres   35076 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 822.2+ KB

# %%
# describe
ipl.describe()
# Out:
#             season  match_number  result_margin  target_runs  target_overs
# count  1169.000000   1169.000000    1146.000000  1163.000000   1163.000000
# mean      9.687767     33.359281      17.364747   167.253654     19.768014
# std       5.253100     19.430749      21.919255    34.222771      1.542583
# min       1.000000      1.000000       1.000000    43.000000      5.000000
# 25%       5.000000     17.000000       6.000000   147.000000     20.000000
# 50%      10.000000     33.000000       8.000000   167.000000     20.000000
# 75%      15.000000     49.000000      20.000000   188.000000     20.000000
# max      18.000000     76.000000     146.000000   288.000000     20.000000

# %%
# isnull
ipl.isnull().sum()
# Out:
# team1               0
# team2               0
# match_date          0
# toss_winner         0
# toss_decision       0
# winner             23
# player_of_match     0
# venue               0
# city               51
# team1_players       0
# team2_players       0
# season              0
# match_number        0
# match_type          0
# result              0
# result_margin      23
# target_runs         6
# target_overs        6
# super_over          0
# dtype: int64

# %%
# duplicate
ipl.duplicated().sum()
# Out:
# 0

# %%
# rename
student
# Out:
#     iq  marks  package     name
# 0  100     90       10   tushar
# 1   90     80        7      ram
# 2  110     95       14  laksham
# 3  120     97       30     veer

# %%
student.rename(columns={'package':'lpa'}, inplace=True)
student # rename is not do permanet change on dataframe, if you want than inplace=True do this.
# Out:
#     iq  marks  lpa     name
# 0  100     90   10   tushar
# 1   90     80    7      ram
# 2  110     95   14  laksham
# 3  120     97   30     veer

# %% [markdown]
# ### Math Methods

# %%
# sum -> axis arguments
print(student)
student.sum(axis=0)
# Out:
#     iq  marks  lpa     name
# 0  100     90   10   tushar
# 1   90     80    7      ram
# 2  110     95   14  laksham
# 3  120     97   30     veer
# iq                        420
# marks                     362
# lpa                        61
# name     tusharramlakshamveer
# dtype: object

# %%
student.mean(axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Downloads/TUSHAR/ai-ml/.venv/lib/python3.8/site-packages/pandas/core/nanops.py:1680, in _ensure_numeric(x)
#    1679 try:
# -> 1680     x = x.astype(np.complex128)
#    1681 except (TypeError, ValueError):
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/Downloads/TUSHAR/ai-ml/.venv/lib/python3.8/site-packages/pandas/core/nanops.py:1683, in _ensure_numeric(x)
#    1682 try:
# -> 1683     x = x.astype(np.float64)
#    1684 except ValueError as err:
#    1685     # GH#29941 we get here with object arrays containing strs
#
# ValueError: could not convert string to float: 'tusharramlakshamveer'
#
# The above exception was the direct cause of the following exception:
# ...

# %%
student.min(axis=0)
# Out:
# iq       90
# marks    80
# lpa       7
# dtype: int64

# %%
student.var(axis=0)
# Out:
# iq       166.666667
# marks     57.666667
# lpa      104.916667
# dtype: float64

# %%
# column
student['lpa']
# Out:
# 0    10
# 1     7
# 2    14
# 3    30
# Name: lpa, dtype: int64

# %%
# multiple column
print(ipl.columns)
ipl[['team1','team2','winner','match_date']]
# Out:
# Index(['team1', 'team2', 'match_date', 'toss_winner', 'toss_decision',
#        'winner', 'player_of_match', 'venue', 'city', 'team1_players',
#        'team2_players', 'season', 'match_number', 'match_type', 'result',
#        'result_margin', 'target_runs', 'target_overs', 'super_over'],
#       dtype='object')
#                             team1                        team2  \
# 0     Royal Challengers Bangalore        Kolkata Knight Riders
# 1                 Kings XI Punjab          Chennai Super Kings
# 2                Delhi Daredevils             Rajasthan Royals
# 3                  Mumbai Indians  Royal Challengers Bangalore
# 4           Kolkata Knight Riders              Deccan Chargers
# ...                           ...                          ...
# 1164         Lucknow Super Giants  Royal Challengers Bengaluru
# 1165                 Punjab Kings  Royal Challengers Bengaluru
# 1166               Mumbai Indians               Gujarat Titans
# ...

# %%
student.set_index('name', inplace=True)
# student

# %% [markdown]
# ### Selecting rows from a DataFrame
# - iloc - searches using index position
# - loc - searches using index labels

# %%
student
# Out:
#           iq  marks  lpa
# name
# tushar   100     90   10
# ram       90     80    7
# laksham  110     95   14
# veer     120     97   30

# %%
# single row
movies.iloc[0]
# Out:
# movieId                                              1
# title                                 Toy Story (1995)
# genres     Adventure|Animation|Children|Comedy|Fantasy
# Name: 0, dtype: object

# %%
# multiple rows
movies.iloc[:5]
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# fancy indexing
movies.iloc[[0,1]]
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
print(student)
# Out:
#           iq  marks  lpa
# name
# tushar   100     90   10
# ram       90     80    7
# laksham  110     95   14
# veer     120     97   30

# %%
# loc
student.loc['tushar']
# Out:
# iq       100
# marks     90
# lpa       10
# Name: tushar, dtype: int64
